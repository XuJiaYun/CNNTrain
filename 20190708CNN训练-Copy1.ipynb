# %%
import os

def getFilePathList(rootDirPath):
    filePath_list = []
    for walk in os.walk(rootDirPath):
        part_filePath_list = [os.path.join(walk[0], file) for file in walk[2]]
        filePath_list.extend(part_filePath_list)
    return filePath_list
filePath_list = getFilePathList('THUCNews')
len(filePath_list)
# Out:
# 836075

# %%
label_list = []
for filePath in filePath_list:
    label = filePath.split('\\')[1]
    label_list.append(label)
len(label_list)
# Out:
# 836075

# %%
import pandas as pd

pd.value_counts(label_list)
# Out:
# 科技    162929
# 股票    154398
# 体育    131604
# 娱乐     92632
# 时政     63086
# 社会     50849
# 教育     41936
# 财经     37098
# 家居     32586
# 游戏     24373
# 房产     20050
# 时尚     13368
# 彩票      7588
# 星座      3578
# dtype: int64

# %%
import pickle

with open('label_list.pickle', 'wb') as file:
    pickle.dump(label_list, file)

# %%
import time
import pickle
import re

def getFile(filePath):
    with open(filePath, encoding='utf8') as file:
        fileStr = ''.join(file.readlines(1000))
    return fileStr

interval = 20000
n_samples = len(label_list)
startTime = time.time()
directory_name = 'content_list'
if not os.path.isdir(directory_name):
    os.mkdir(directory_name)
content_list = []
for i in range(0, n_samples, interval):
    startIndex = i
    endIndex = i + interval
    save_list = []
    print('%06d-%06d start' %(startIndex, endIndex))
    for filePath in filePath_list[startIndex:endIndex]:
        fileStr = getFile(filePath)
        content = re.sub('\s+', ' ', fileStr)
        content_list.append(content)
        save_list.append(content)
    save_fileName = directory_name + '/%06d-%06d.pickle' %(startIndex, endIndex)
    with open(save_fileName, 'wb') as file:
        pickle.dump(save_list, file)
    used_time = time.time() - startTime
    print('%06d-%06d used time: %.2f seconds' %(startIndex, endIndex, used_time))
# Out:
# 000000-020000 start
# 000000-020000 used time: 20.08 seconds
# 020000-040000 start
# 020000-040000 used time: 38.97 seconds
# 040000-060000 start
# 040000-060000 used time: 58.98 seconds
# 060000-080000 start
# 060000-080000 used time: 80.67 seconds
# 080000-100000 start
# 080000-100000 used time: 99.42 seconds
# 100000-120000 start
# 100000-120000 used time: 118.73 seconds
# 120000-140000 start
# 120000-140000 used time: 138.33 seconds
# 140000-160000 start
# 140000-160000 used time: 158.95 seconds
# 160000-180000 start
# 160000-180000 used time: 177.00 seconds
# 180000-200000 start
# 180000-200000 used time: 196.47 seconds
# 200000-220000 start
# 200000-220000 used time: 215.82 seconds
# 220000-240000 start
# 220000-240000 used time: 233.28 seconds
# 240000-260000 start
# 240000-260000 used time: 251.94 seconds
# 260000-280000 start
# 260000-280000 used time: 272.55 seconds
# 280000-300000 start
# 280000-300000 used time: 292.95 seconds
# 300000-320000 start
# 300000-320000 used time: 314.43 seconds
# 320000-340000 start
# 320000-340000 used time: 332.89 seconds
# 340000-360000 start
# 340000-360000 used time: 351.62 seconds
# 360000-380000 start
# 360000-380000 used time: 370.83 seconds
# 380000-400000 start
# 380000-400000 used time: 388.54 seconds
# 400000-420000 start
# 400000-420000 used time: 406.58 seconds
# 420000-440000 start
# 420000-440000 used time: 425.12 seconds
# 440000-460000 start
# 440000-460000 used time: 447.93 seconds
# 460000-480000 start
# 460000-480000 used time: 466.88 seconds
# 480000-500000 start
# 480000-500000 used time: 484.20 seconds
# 500000-520000 start
# 500000-520000 used time: 501.45 seconds
# 520000-540000 start
# 520000-540000 used time: 521.43 seconds
# 540000-560000 start
# 540000-560000 used time: 540.28 seconds
# 560000-580000 start
# 560000-580000 used time: 562.40 seconds
# 580000-600000 start
# 580000-600000 used time: 581.91 seconds
# 600000-620000 start
# 600000-620000 used time: 600.35 seconds
# 620000-640000 start
# 620000-640000 used time: 620.86 seconds
# 640000-660000 start
# 640000-660000 used time: 640.48 seconds
# 660000-680000 start
# 660000-680000 used time: 656.68 seconds
# 680000-700000 start
# 680000-700000 used time: 675.40 seconds
# 700000-720000 start
# 700000-720000 used time: 695.76 seconds
# 720000-740000 start
# 720000-740000 used time: 714.53 seconds
# 740000-760000 start
# 740000-760000 used time: 734.86 seconds
# 760000-780000 start
# 760000-780000 used time: 756.67 seconds
# 780000-800000 start
# 780000-800000 used time: 776.81 seconds
# 800000-820000 start
# 800000-820000 used time: 795.32 seconds
# 820000-840000 start
# 820000-840000 used time: 811.45 seconds

# %%
from collections import Counter 
def getVocabularyList(content_list, vocabulary_size):
    allContent_str = ''.join(content_list)
    print(len(allContent_str))
    counter = Counter(allContent_str)
    vocabulary_list = [k[0] for k in counter.most_common(vocabulary_size)]
    print(vocabulary_list)
    return ['PAD'] + vocabulary_list
startTime = time.time()
vocabulary_list = getVocabularyList(content_list, 10000)
used_time = time.time() - startTime
print('used time: %.2f seconds' %used_time)
# Out:
# 563447654
# ['，', '的', ' ', '。', '0', '1', '一', '在', '是', '2', '了', '有', '中', '不', '、', '上', '大', '人', '国', '为', '年', '“', '3', '”', '5', '时', '这', '出', '个', '和', '日', '到', '以', '场', '对', '会', '4', '.', '行', '来', '8', '9', '后', '他', '能', '6', '下', '新', '分', '我', '业', '发', '前', '市', '于', '月', '：', '成', '家', '7', '公', '将', '生', '要', '现', '高', '经', '也', '多', ')', '(', '可', '元', '们', '过', '比', '球', '金', '机', '本', '股', '方', '地', '开', '赛', '用', '者', '最', '得', '美', '就', '而', '网', '进', '自', '期', '点', '作', '报', '资', '表', '面', '主', '动', '队', '还', '学', '说', '同', '之', '但', '天', 'e', '全', '与', '体', '力', '其', '%', '电', '价', '产', '-', '利', '都', '手', '内', '间', '小', '部', '加', '次', '度', '数', '外', '司', '名', '已', '长', '此', '合', '目', '斯', 'o', '第', '理', '子', '当', '实', '定', 'i', 'a', '关', '好', '基', '重', '示', '所', '两', '员', '看', '等', '品', '通', '三', '入', '相', '并', '万', '位', '很', '因', '然', '事', '明', '情', '考', 'n', '没', '工', '从', '平', '更', '信', '法', '被', '尔', '心', '联', '计', '如', '持', '据', '今', '记', '道', '特', '》', '《', '里', '收', 'A', '商', '投', '交', '及', '指', 'C', '提', '格', '至', '性', '布', '周', '意', 'S', '务', '着', '正', 'r', '增', '去', '起', '打', '受', '息', '只', '该', '近', '北', '回', '身', '量', '无', '保', '接', '线', '区', '总', '调', '强', '些', 'D', '果', '应', 'P', '文', '消', '达', '门', '西', 't', '亿', '认', '盘', '政', '海', '展', '；', '女', '由', '化', '民', '德', '样', '向', '式', '安', '证', '续', '科', '京', '影', '战', '让', '己', '系', '问', '马', 'M', '制', '常', '东', '视', '季', '首', '二', '选', '显', '亚', '建', '题', '势', '克', '感', '称', '讯', '色', 'T', '华', 'I', '拉', '涨', 'l', '车', '乐', '种', '预', '想', '费', 's', '约', '结', '管', '传', '头', '再', '她', '户', '给', '跌', '低', '设', '超', '整', '那', '非', '水', '台', '解', '较', '做', '支', '么', '板', '运', '先', 'G', '张', '直', '任', '评', '处', '少', '升', '论', '组', '率', '级', '易', '活', '反', '取', '未', '使', '份', '告', '英', '件', '专', '推', '浪', 'B', '单', '房', '游', '巴', '别', '友', '款', '原', '银', '广', '？', '演', '代', '幅', '每', 'E', '世', '技', '变', '求', '需', '士', '购', '图', '阿', '统', '观', '走', '老', '卡', '注', '获', 'm', '集', '你', '院', '规', '风', '型', '尼', '王', '节', '放', '望', '米', '/', '带', '济', '各', '光', '备', '流', '军', '程', '路', '四', '像', '知', 'd', '足', '售', '标', '口', '局', '参', '具', '术', '罗', '值', '教', '决', '始', '际', '物', 'c', '准', '或', '领', '完', '立', '界', '议', '连', '话', '采', '造', '导', '星', 'O', '仅', '空', '几', '转', '企', '试', '创', '快', '片', '销', '南', '港', '城', '博', '热', '项', '十', '复', '客', '查', '营', '育', '欧', '戏', '则', '李', '团', '权', '奥', '服', 'h', '均', '随', '供', '半', '站', '校', '功', '速', '击', '步', '案', '—', '师', '气', '号', '确', '难', '货', '配', 'H', '深', '终', '又', '维', '希', '包', '况', '引', '质', '双', '优', '财', '容', '即', '何', '兰', 'L', '昨', '男', '才', 'F', '装', 'N', '！', '失', '太', '助', '拍', '胜', '效', '山', '媒', '某', '且', '形', '真', '把', '买', '仍', '划', '见', '牌', '爱', '清', '响', '火', '改', '模', '置', '研', '言', '继', '存', '段', '警', '排', '类', '融', '微', '票', 'u', '共', '普', '根', '办', '红', '态', '降', '林', '居', '曾', '策', '器', '防', '众', '环', '五', '争', '招', '照', '录', '底', '举', '社', '券', '午', '绩', '奖', '却', '儿', '控', '精', '晚', '离', '早', '额', '素', '便', '什', '住', '越', '络', 'V', '练', '攻', '构', '花', '索', '许', '短', '除', '致', '源', '限', '冠', '请', '险', '纳', '破', '州', '候', '另', '负', '篮', '百', '列', '伤', '益', 'R', '料', '陈', '条', '断', '黄', '府', '卫', '边', '角', '满', '算', '油', '剧', '虽', '落', '够', '轮', '歌', 'p', '减', '频', '夫', '突', '摄', '块', '露', '觉', '测', 'g', '协', '往', '钟', '波', '医', '必', '历', '否', '极', '轻', '刚', '尽', '景', '属', '象', '依', '洲', '压', '香', '富', '兴', '声', '积', '刘', '拿', '白', '切', '岁', '音', '究', '江', 'y', '席', '·', '职', '欢', '宣', '官', '志', '留', '奇', '移', '初', '访', '择', '版', '玩', '施', '店', '书', '责', '神', '佳', 'K', '它', '远', '宝', '币', '停', 'b', '省', '围', '字', '稳', '监', '彩', '状', '透', '委', '材', '送', '债', 'W', '钱', '验', '亲', '左', '范', '担', '谈', '楼', '判', '龙', '喜', '诉', '独', '占', '析', '石', '语', ',', '互', '阳', '闻', '右', '按', '黑', '紧', '孩', '笔', '迷', '习', '伊', '找', '弹', 'k', '托', '班', '命', '括', '卖', '史', '待', '批', '核', '换', '套', '申', '雷', '疑', 'X', '尚', '纪', '拥', '令', '韩', '死', '婚', '码', '福', '激', '止', '错', '层', '略', '森', '诺', '适', 'w', ...
# used time: 55.72 seconds

# %%
import pickle 

with open('vocabulary_list.pickle', 'wb') as file:
    pickle.dump(vocabulary_list, file)

# %%
def text_save(filename, data):#filename为写入CSV文件的路径，data为要写入数据列表.
    file = open(filename,'w',encoding='utf-8')
    for i in range(len(data)):
        s = str(data[i]).replace('[','').replace(']','')#去除[],这两行按数据不同，可以选择
        s = s.replace("'",'').replace(',','') +'\n'   #去除单引号，逗号，每行末尾追加换行符
        file.write(s)
    file.close()
    print("保存文件成功") 
text_save('vocabulary.txt',vocabulary_list)
# Out:
# 保存文件成功

# %%
import pickle

with open('vocabulary_list.pickle', 'rb') as file:
    vocabulary_list = pickle.load(file)

# %%
import time
startTime = time.time()
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(content_list, label_list)
train_content_list = train_X
train_label_list = train_y
test_content_list = test_X
test_label_list = test_y
used_time = time.time() - startTime
print('train_test_split used time : %.2f seconds' %used_time)
vocabulary_size = 10000  # 词汇表达小
sequence_length = 600  # 序列长度
embedding_size = 64  # 词向量维度
num_filters = 256  # 卷积核数目
filter_size = 5  # 卷积核尺寸
num_fc_units = 128  # 全连接层神经元
dropout_keep_probability = 0.5  # dropout保留比例
learning_rate = 1e-3  # 学习率
batch_size = 64  # 每批训练大小
word2id_dict = dict([(b, a) for a, b in enumerate(vocabulary_list)])
content2idList = lambda content : [word2id_dict[word] for word in content if word in word2id_dict]
train_idList_list = [content2idList(content) for content in train_content_list]
used_time = time.time() - startTime
print('content2idList used time : %.2f seconds' %used_time)
import numpy as np
num_classes = np.unique(label_list).shape[0]
import tensorflow.contrib.keras as kr
train_X = kr.preprocessing.sequence.pad_sequences(train_idList_list, sequence_length)
from sklearn.preprocessing import LabelEncoder
labelEncoder = LabelEncoder()
train_y = labelEncoder.fit_transform(train_label_list)
train_Y = kr.utils.to_categorical(train_y, num_classes)
import tensorflow as tf
tf.reset_default_graph()
X_holder = tf.placeholder(tf.int32, [None, sequence_length],name = 'X_holder')
Y_holder = tf.placeholder(tf.float32, [None, num_classes],name = 'Y_holder')
used_time = time.time() - startTime
print('data preparation used time : %.2f seconds' %used_time)
# Out:
# train_test_split used time : 1.31 seconds
# content2idList used time : 63.13 seconds
# data preparation used time : 85.22 seconds

# %%
embedding = tf.get_variable('embedding', 
                            [vocabulary_size, embedding_size])
embedding_inputs = tf.nn.embedding_lookup(embedding,
                                          X_holder)
conv = tf.layers.conv1d(embedding_inputs,
                        num_filters,
                        filter_size)
max_pooling = tf.reduce_max(conv, 
                            [1])
full_connect = tf.layers.dense(max_pooling,
                               num_fc_units)
full_connect_dropout = tf.contrib.layers.dropout(full_connect, 
                                                 keep_prob=dropout_keep_probability)
full_connect_activate = tf.nn.relu(full_connect_dropout)
softmax_before = tf.layers.dense(full_connect_activate,
                                 num_classes)
predict_Y = tf.nn.softmax(softmax_before,name = 'predict_Y')
cross_entropy = tf.nn.softmax_cross_entropy_with_logits_v2(labels=Y_holder,
                                                           logits=softmax_before)
loss = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate)
train = optimizer.minimize(loss)
isCorrect = tf.equal(tf.argmax(Y_holder, 1), tf.argmax(predict_Y, 1))
accuracy = tf.reduce_mean(tf.cast(isCorrect, tf.float32))

# %%
init = tf.global_variables_initializer()
session = tf.Session()
session.run(init)

# %%
test_idList_list = [content2idList(content) for content in test_content_list]
test_X = kr.preprocessing.sequence.pad_sequences(test_idList_list, sequence_length)
test_y = labelEncoder.transform(test_label_list)
test_Y = kr.utils.to_categorical(test_y, num_classes)
import random
for i in range(20000):
    selected_index = random.sample(list(range(len(train_y))), k=batch_size)
    batch_X = train_X[selected_index]
    batch_Y = train_Y[selected_index]
    session.run(train, {X_holder:batch_X, Y_holder:batch_Y})
    step = i + 1 
    if step % 100 == 0:
        selected_index = random.sample(list(range(len(test_y))), k=200)
        batch_X = test_X[selected_index]
        batch_Y = test_Y[selected_index]
        loss_value, accuracy_value = session.run([loss, accuracy], {X_holder:batch_X, Y_holder:batch_Y})
        print('step:%d loss:%.4f accuracy:%.4f' %(step, loss_value, accuracy_value))
# Out:
# step:100 loss:1.4245 accuracy:0.5900
# step:200 loss:0.9570 accuracy:0.7050
# step:300 loss:0.6793 accuracy:0.8200
# step:400 loss:0.6045 accuracy:0.8350
# step:500 loss:0.6531 accuracy:0.8000
# step:600 loss:0.4596 accuracy:0.8650
# step:700 loss:0.6544 accuracy:0.8250
# step:800 loss:0.5148 accuracy:0.8850
# step:900 loss:0.4798 accuracy:0.8850
# step:1000 loss:0.4470 accuracy:0.8650
# step:1100 loss:0.4500 accuracy:0.8800
# step:1200 loss:0.5635 accuracy:0.8500
# step:1300 loss:0.4207 accuracy:0.8800
# step:1400 loss:0.3783 accuracy:0.8650
# step:1500 loss:0.4152 accuracy:0.8850
# step:1600 loss:0.4820 accuracy:0.8750
# step:1700 loss:0.3113 accuracy:0.9150
# step:1800 loss:0.3249 accuracy:0.9000
# step:1900 loss:0.2562 accuracy:0.9250
# step:2000 loss:0.2767 accuracy:0.9150
# step:2100 loss:0.2521 accuracy:0.9050
# step:2200 loss:0.2639 accuracy:0.9300
# step:2300 loss:0.3770 accuracy:0.8750
# step:2400 loss:0.2161 accuracy:0.9400
# step:2500 loss:0.3699 accuracy:0.8950
# step:2600 loss:0.3282 accuracy:0.9150
# step:2700 loss:0.4710 accuracy:0.8850
# step:2800 loss:0.2655 accuracy:0.9000
# step:2900 loss:0.2775 accuracy:0.8950
# step:3000 loss:0.2737 accuracy:0.9350
# step:3100 loss:0.2310 accuracy:0.9200
# step:3200 loss:0.3244 accuracy:0.8900
# step:3300 loss:0.4411 accuracy:0.8950
# step:3400 loss:0.3992 accuracy:0.8750
# step:3500 loss:0.2734 accuracy:0.9300
# step:3600 loss:0.3286 accuracy:0.8800
# step:3700 loss:0.2770 accuracy:0.9300
# step:3800 loss:0.2698 accuracy:0.9100
# step:3900 loss:0.2950 accuracy:0.9050
# step:4000 loss:0.2630 accuracy:0.9150
# step:4100 loss:0.3896 accuracy:0.8850
# step:4200 loss:0.2703 accuracy:0.9300
# step:4300 loss:0.2481 accuracy:0.9200
# step:4400 loss:0.3557 accuracy:0.9200
# step:4500 loss:0.3238 accuracy:0.9050
# step:4600 loss:0.3135 accuracy:0.9250
# step:4700 loss:0.2655 accuracy:0.9100
# step:4800 loss:0.2189 accuracy:0.9250
# step:4900 loss:0.2924 accuracy:0.9050
# step:5000 loss:0.1883 accuracy:0.9150
# step:5100 loss:0.3093 accuracy:0.9150
# step:5200 loss:0.3473 accuracy:0.8950
# step:5300 loss:0.2062 accuracy:0.9200
# step:5400 loss:0.3282 accuracy:0.9150
# step:5500 loss:0.1814 accuracy:0.9450
# step:5600 loss:0.1975 accuracy:0.9400
# step:5700 loss:0.2057 accuracy:0.9400
# step:5800 loss:0.3400 accuracy:0.9000
# step:5900 loss:0.3450 accuracy:0.8700
# step:6000 loss:0.2621 accuracy:0.9350
# step:6100 loss:0.2443 accuracy:0.9350
# step:6200 loss:0.3833 accuracy:0.9000
# step:6300 loss:0.3276 accuracy:0.8950
# step:6400 loss:0.2701 accuracy:0.9100
# step:6500 loss:0.2871 accuracy:0.9000
# step:6600 loss:0.3083 accuracy:0.9250
# step:6700 loss:0.3181 accuracy:0.9050
# step:6800 loss:0.4200 accuracy:0.8950
# step:6900 loss:0.3242 accuracy:0.9150
# step:7000 loss:0.3561 accuracy:0.9100
# step:7100 loss:0.3015 accuracy:0.9000
# step:7200 loss:0.3132 accuracy:0.9150
# step:7300 loss:0.3114 accuracy:0.9100
# step:7400 loss:0.3577 accuracy:0.9000
# step:7500 loss:0.3215 accuracy:0.9150
# step:7600 loss:0.3520 accuracy:0.9050
# step:7700 loss:0.2054 accuracy:0.9150
# step:7800 loss:0.3112 accuracy:0.9100
# step:7900 loss:0.2705 accuracy:0.9050
# step:8000 loss:0.2519 accuracy:0.9250
# step:8100 loss:0.3156 accuracy:0.9150
# step:8200 loss:0.3221 accuracy:0.9000
# step:8300 loss:0.2548 accuracy:0.9250
# step:8400 loss:0.3118 accuracy:0.9150
# step:8500 loss:0.2857 accuracy:0.9250
# step:8600 loss:0.3012 accuracy:0.9250
# step:8700 loss:0.3093 accuracy:0.9000
# step:8800 loss:0.2140 accuracy:0.9550
# step:8900 loss:0.3271 accuracy:0.8950
# step:9000 loss:0.3193 accuracy:0.9150
# step:9100 loss:0.3135 accuracy:0.9000
# step:9200 loss:0.2578 accuracy:0.9400
# step:9300 loss:0.3693 accuracy:0.9150
# step:9400 loss:0.2165 accuracy:0.9400
# step:9500 loss:0.2084 accuracy:0.9350
# step:9600 loss:0.3676 accuracy:0.9200
# step:9700 loss:0.2061 accuracy:0.9400
# step:9800 loss:0.2755 accuracy:0.9250
# step:9900 loss:0.2473 accuracy:0.9150
# step:10000 loss:0.2713 accuracy:0.9150
# step:10100 loss:0.3676 accuracy:0.9200
# step:10200 loss:0.1980 accuracy:0.9450
# step:10300 loss:0.3354 accuracy:0.9050
# step:10400 loss:0.2743 accuracy:0.9200
# step:10500 loss:0.2751 accuracy:0.9100
# step:10600 loss:0.3284 accuracy:0.9150
# step:10700 loss:0.1784 accuracy:0.9450
# step:10800 loss:0.2220 accuracy:0.9350
# step:10900 loss:0.2723 accuracy:0.9000
# step:11000 loss:0.2713 accuracy:0.9150
# step:11100 loss:0.2356 accuracy:0.9200
# step:11200 loss:0.3385 accuracy:0.9000
# step:11300 loss:0.2447 accuracy:0.9300
# step:11400 loss:0.3039 accuracy:0.9450
# step:11500 loss:0.3759 accuracy:0.8900
# step:11600 loss:0.3240 accuracy:0.9200
# step:11700 loss:0.2647 accuracy:0.9100
# step:11800 loss:0.1970 accuracy:0.9100
# step:11900 loss:0.3147 accuracy:0.9350
# step:12000 loss:0.2275 accuracy:0.9450
# step:12100 loss:0.2288 accuracy:0.9300
# step:12200 loss:0.2747 accuracy:0.9150
# step:12300 loss:0.3657 accuracy:0.8950
# step:12400 loss:0.1894 accuracy:0.9450
# step:12500 loss:0.1182 accuracy:0.9600
# step:12600 loss:0.3219 accuracy:0.9200
# step:12700 loss:0.2044 accuracy:0.9250
# step:12800 loss:0.2648 accuracy:0.8850
# step:12900 loss:0.3111 accuracy:0.9050
# step:13000 loss:0.2308 accuracy:0.9450
# step:13100 loss:0.2249 accuracy:0.9400
# step:13200 loss:0.2526 accuracy:0.9100
# step:13300 loss:0.2745 accuracy:0.9100
# step:13400 loss:0.4624 accuracy:0.8950
# step:13500 loss:0.3250 accuracy:0.9200
# step:13600 loss:0.3252 accuracy:0.9050
# step:13700 loss:0.2690 accuracy:0.9200
# step:13800 loss:0.3876 accuracy:0.8950
# step:13900 loss:0.2270 accuracy:0.9300
# step:14000 loss:0.2879 accuracy:0.9250
# step:14100 loss:0.3562 accuracy:0.9200
# step:14200 loss:0.2478 accuracy:0.9250
# step:14300 loss:0.1634 accuracy:0.9600
# step:14400 loss:0.2322 accuracy:0.9450
# step:14500 loss:0.2664 accuracy:0.9300
# step:14600 loss:0.2792 accuracy:0.9300
# step:14700 loss:0.2972 accuracy:0.9300
# step:14800 loss:0.3391 accuracy:0.8900
# step:14900 loss:0.2801 accuracy:0.9300
# step:15000 loss:0.2819 accuracy:0.9350
# step:15100 loss:0.1279 accuracy:0.9650
# step:15200 loss:0.3340 accuracy:0.9150
# step:15300 loss:0.3003 accuracy:0.9350
# step:15400 loss:0.3039 accuracy:0.9150
# step:15500 loss:0.4186 accuracy:0.8650
# step:15600 loss:0.2149 accuracy:0.9400
# step:15700 loss:0.2248 accuracy:0.9100
# step:15800 loss:0.4550 accuracy:0.9000
# step:15900 loss:0.2736 accuracy:0.9100
# step:16000 loss:0.2717 accuracy:0.9250
# step:16100 loss:0.1108 accuracy:0.9650
# step:16200 loss:0.3445 accuracy:0.9200
# step:16300 loss:0.3234 accuracy:0.9050
# step:16400 loss:0.1973 accuracy:0.9350
# step:16500 loss:0.2484 accuracy:0.9050
# step:16600 loss:0.3180 accuracy:0.9150
# step:16700 loss:0.3459 accuracy:0.8950
# step:16800 loss:0.2933 accuracy:0.9200
# step:16900 loss:0.2347 accuracy:0.9550
# step:17000 loss:0.2362 accuracy:0.9200
# step:17100 loss:0.2805 accuracy:0.9300
# step:17200 loss:0.2316 accuracy:0.9300
# step:17300 loss:0.3096 accuracy:0.9100
# step:17400 loss:0.3827 accuracy:0.8950
# step:17500 loss:0.2942 accuracy:0.9400
# step:17600 loss:0.1798 accuracy:0.9400
# step:17700 loss:0.2333 accuracy:0.9400
# step:17800 loss:0.3846 accuracy:0.9050
# step:17900 loss:0.4351 accuracy:0.8750
# step:18000 loss:0.1963 accuracy:0.9500
# step:18100 loss:0.2410 accuracy:0.9200
# step:18200 loss:0.1513 accuracy:0.9550
# step:18300 loss:0.3675 accuracy:0.9150
# step:18400 loss:0.3031 accuracy:0.9050
# step:18500 loss:0.2340 accuracy:0.9200
# step:18600 loss:0.2903 accuracy:0.9150
# step:18700 loss:0.2585 accuracy:0.9400
# step:18800 loss:0.2605 accuracy:0.9150
# step:18900 loss:0.1715 accuracy:0.9450
# step:19000 loss:0.3164 accuracy:0.9350
# step:19100 loss:0.2828 accuracy:0.9350
# step:19200 loss:0.2090 accuracy:0.9300
# step:19300 loss:0.2863 accuracy:0.9100
# step:19400 loss:0.2652 accuracy:0.9250
# step:19500 loss:0.2797 accuracy:0.9250
# step:19600 loss:0.2895 accuracy:0.9200
# step:19700 loss:0.1956 accuracy:0.9350
# step:19800 loss:0.3400 accuracy:0.9200
# step:19900 loss:0.1971 accuracy:0.9300
# step:20000 loss:0.2400 accuracy:0.9350

# %%
import warnings
warnings.filterwarnings("ignore")
def predict(input_content):
    #idList的数据类型必须是列表list，
    #否则调用kr.preprocessing.sequence.pad_sequences方法会报错
    idList = [content2idList(input_content)]
    X = kr.preprocessing.sequence.pad_sequences(idList, sequence_length)
    Y = session.run(predict_Y, {X_holder:X})
    y = np.argmax(Y, axis=1)
    label = labelEncoder.inverse_transform(y)[0]
    return label

selected_index = random.sample(range(len(test_content_list)), k=1)[0]
selected_sample = test_content_list[selected_index]
true_label = test_label_list[selected_index]
predict_label = predict(selected_sample)
print('selected_sample :', selected_sample)
print('true_label :', true_label)
print('predict_label :', predict_label, '\n')
print('predict whatever you want, for example:')
input_content = "别让程序员身份抹杀了你的感性"
print('predict("%s") :' %input_content, predict(input_content))
# Out:
# selected_sample : DND新作《龙与地下城：匕首谷》前瞻 3月28日，Atari公布了基于龙与地下城设定的新作，《龙与地下城：匕首谷(Dungeons & Dragons：Daggerdale)》的进一步情报，同时公布了游戏的多张截图。 《龙与地下城：匕首谷》是一款动作角色扮演游戏，由Bedlam Studios开发，Atari担任发行。游戏预定推出PC、PS3和 Xbox360版。本作故事围绕在主角为了守护Dalelands的和平，奋而与企图入侵、征服Dalelands的邪恶力量Rezlus和Zhentarim进行战斗。 游戏除了提供单人故事模式以外，还支持四人在线同乐和两人区网合作的多人游戏模式，玩家的任务就是藉由解开Techyamar矿山的谜团来恢复Dalelands昔日的和平，摧毁邪恶势力所在地虚空之塔(Tower of the Void)，并与最后的魔王Rezlus战斗。 在《龙与地下城：匕首谷》中，玩家可以单独游戏，也可以和好友一同闯关，游戏中允许最多4名玩家一起游戏。游戏中将有大量的武器、技能、特技可以供玩家使用和修习。 《龙与地下城：匕首谷》预定于2011年春季发售，将登陆PC、Xbox Live Arcade和PSN平台。 编译/熊猫
# true_label : 游戏
# predict_label : 游戏
#
# predict whatever you want, for example:
# predict("别让程序员身份抹杀了你的感性") : 家居

# %%
import numpy as np
import pandas as pd
import time
from sklearn.metrics import confusion_matrix

def predictAll(test_X, batch_size=100):
    predict_value_list = []
    for i in range(0, len(test_X), batch_size):
        selected_X = test_X[i: i + batch_size]
        predict_value = session.run(predict_Y, {X_holder:selected_X})
        predict_value_list.extend(predict_value)
    return np.array(predict_value_list)



pd.set_option('display.max_rows',500)
pd.set_option('display.max_columns',500)
pd.set_option('display.width',1500)
startTime = time.time()
print(' start time : %.2f seconds' %startTime)
Y = predictAll(test_X)
y = np.argmax(Y, axis=1)
predict_label_list = labelEncoder.inverse_transform(y)
df = pd.DataFrame(confusion_matrix(test_label_list, predict_label_list), 
             columns=labelEncoder.classes_,
             index=labelEncoder.classes_ )
used_time = time.time()-startTime
print(' used time : %.2f seconds' %used_time)
print(df)
# Out:
#  start time : 1563516511.04 seconds
#  used time : 228.13 seconds
#        体育     娱乐    家居    彩票    房产    教育    时尚     时政   星座    游戏     社会     科技     股票    财经
# 体育  32440    242    16    53     6    29    10     66    3    15    129     40     16     0
# 娱乐    143  22231    36     1     3    40    59     85    8    30    287    109     20    10
# 家居     24    178  7410     0    35    32    77     29   10    12     61    224     50    12
# 彩票    135      2     1  1678     0     2     2      3    0     2     45      5      3     0
# 房产      9     23   108     2  4563    26     2     35    2     0     86     39    120    28
# 教育     37    129    28     4     8  9810    25    157   10    21    306    122     28    12
# 时尚     26    162    66     2     1    26  2917     18   12    14     49     44      6     3
# 时政     91    217    21     9    45   194    23  14115    0    11    492    329    309    44
# 星座      3     22    16     0     0    32    27      4  688     5     21      5      0     1
# 游戏     42    122     9     2     0    10    13     17    8  5351     36    402     13     2
# 社会     69    321    28    41    26   289    14    323    2     6  11044    332     21    16
# 科技     75    533   155     7    25   195    39    429    0   395    673  37343    423    46
# 股票     17     86    70     9   121    49     5    462    2    16     63   1073  35937   937
# 财经      7     66    20    15    49    28     7     83    2     1    157    171    941  7759

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support

def eval_model(y_true, y_pred, labels):
    # 计算每个分类的Precision, Recall, f1, support
    p, r, f1, s = precision_recall_fscore_support(y_true, y_pred)
    # 计算总体的平均Precision, Recall, f1, support
    tot_p = np.average(p, weights=s)
    tot_r = np.average(r, weights=s)
    tot_f1 = np.average(f1, weights=s)
    tot_s = np.sum(s)
    res1 = pd.DataFrame({
        u'Label': labels,
        u'Precision': p,
        u'Recall': r,
        u'F1': f1,
        u'Support': s
    })
    res2 = pd.DataFrame({
        u'Label': ['总体'],
        u'Precision': [tot_p],
        u'Recall': [tot_r],
        u'F1': [tot_f1],
        u'Support': [tot_s]
    })
    res2.index = [999]
    res = pd.concat([res1, res2])
    return res[['Label', 'Precision', 'Recall', 'F1', 'Support']]

print(eval_model(test_label_list, predict_label_list, labelEncoder.classes_))
# Out:
#     Label  Precision    Recall        F1  Support
# 0      体育   0.979528  0.981098  0.980312    33065
# 1      娱乐   0.913578  0.963967  0.938096    23062
# 2      家居   0.928106  0.908756  0.918329     8154
# 3      彩票   0.920461  0.893504  0.906782     1878
# 4      房产   0.934658  0.904819  0.919496     5043
# 5      教育   0.911541  0.917080  0.914302    10697
# 6      时尚   0.905901  0.871787  0.888517     3346
# 7      时政   0.891887  0.887736  0.889806    15900
# 8      星座   0.921017  0.834951  0.875875      824
# 9      游戏   0.910189  0.887838  0.898875     6027
# 10     社会   0.821176  0.881264  0.850160    12532
# 11     科技   0.928053  0.925752  0.926901    40338
# 12     股票   0.948531  0.925091  0.936664    38847
# 13     财经   0.874746  0.833763  0.853763     9306
# 999    总体   0.925223  0.924729  0.924758   209019

# %% [raw]
# 保存模型

# %%
saver = tf.train.Saver()
saver.save(session,"model_ckpt/model.ckpt")
# Out:
# 'model_ckpt/model.ckpt'

# %%
builder = tf.saved_model.builder.SavedModelBuilder('model_pb/')
builder.add_meta_graph_and_variables(session,["20190718"])
builder.save()
# Out:
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: model_pb/saved_model.pb
# b'model_pb/saved_model.pb'
